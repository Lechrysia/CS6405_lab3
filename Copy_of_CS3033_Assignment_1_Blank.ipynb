# %% [markdown]
# <a href="https://colab.research.google.com/github/Lechrysia/CS6405_lab3/blob/main/Copy_of_CS3033_Assignment_1_Blank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Load the dataset on Colab
# # 2. Display the attributes' name and their data type
# import pandas as pd
# import numpy as np
#
# titanic = pd.read_csv("https://github.com/andvise/DataAnalyticsDatasets/blob/16ca8de1233c8643bfe85fcd1cd87c9ff2221312/titanic.csv?raw=True")

# %% [markdown]
# # Part 2 - k-NN implementation

# %% [markdown]
# The confusion matrix shows that ....

# %% [markdown]
# # Part 3 - Hyperparameters search

# %%
# your code here

# %% [markdown]
# The best k is ...  Because ...

# %% [markdown]
# # Part 4 - Weighted k-NN

# %%
# your code here

# %% [markdown]
# Comment the results here.
